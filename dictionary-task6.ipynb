# %%
my_dict={'key1':'hello','key2':'any value'}

# %%
my_dict['key1']
# Out:
# 'hello'

# %%
my_dict={'key1':123,'key2':[12,22,33],'key3':['item0','item1','item2']}

# %%
my_dict['key3']
# Out:
# ['item0', 'item1', 'item2']

# %%
my_dict['key3'][0]
# Out:
# 'item0'

# %%
my_dict['key3'][0][0].upper()
# Out:
# 'I'

# %%
my_dict['key1']
# Out:
# 123

# %%
my_dict['key1']-=123

# %%
my_dict['key1']
# Out:
# 0

# %%
my_dict['key1'] -= 123
my_dict['key1']
# Out:
# -123

# %%
d={}

# %%
d['animal']='dog'

# %%
d['answer']=42

# %%
d
# Out:
# {'animal': 'dog', 'answer': 42}

# %%
d = {'key1':{'nestkey':{'subnestkey':'value'}}}

# %%
d['key1']['nestkey']['subnestkey']
# Out:
# 'value'

# %%
d = {'key1':1,'key2':2,'key3':3}

# %%
d.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3)])
